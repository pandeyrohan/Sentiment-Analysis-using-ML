# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.yelp.com/biz/tesla-san-francisco?osq=Tesla+Dealership')

# %%
print(r.status_code)
# Out:
# 200

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><script async src="https://www.googletagmanager.com/gtag/js?id=G-K9Z2ZEVC8C&l=ga4DataLayer"></script><script>window.ga4DataLayer=window.ga4DataLayer||[];function ga4Tag(){ga4DataLayer.push(arguments);};ga4Tag("js",new Date());ga4Tag("config","G-K9Z2ZEVC8C",{send_page_view:false});</script><meta id="emotion-container"><style data-emotion-css="0 xl0fej ymzf9m zar4qi 13merx8 79elbk 12il5ah 7z2yta 1llfbb7 aurft1 z8bp47 1r871ch 1qjitbm 1evauet 1iuvwzi 1food7o 1enow5j ije6j5 1fygppl 1m77lek 9vivtc 1sb02f4 ralh0w 1sp70ar 1u89q5b wonnhn w8rns 1fkqezt 1pz4y59 ux5mu6 1m051bw qgunke 1nrzw89 1fnccdf chan6m 6a0jil 15ai72i inq9gi 1c2abjj 12i50in kma813 15j7fnr war30n 1lr1m88 1oibaro 13zxenj 8dlaw4 xlzvdl 1b3q7j6 foyide 1lx34my 144i0wq 1kq79li 1rjq8gp 16agjqd 1uk2nuw cmnlx9 1sie4w0 jb304u rvoh79 1c994ch 6279gn 1s785lv 18k2l6p 1nr6fnq dip4y5 1ynt373 1xuen6g 2v2z39 108mqsh 4uph24 1d0cqww 4zp531 8f8xdi 1h0y4i5 e29med 1m2gifa dh50jt yyr98k 4mfze4 1jac6c2 cv1jz2 ddqa90 fksa8h n65gq3 dew2bp 19sk4h4 147xtl9 gutk1c jb5mb6 1w0hvwb 1se8maq 1p9ibgf 1ufst7j wzaofb syqjjh qyp8bo 1qly8nt tza3mu 19cdu5a 1r80nfg 1xluaz5 142tcj8 2sacua 1fliqpp r9996t 1um3nx 1jtriov 29kerx 1hgawz4 106vfgv 4g6ai3 lziufc 1xkgsub w1k3wh ee59jl 1oiyjl1 lsbzdp 9zvmc3 1p80smk 1vhakgw rlqqlq 12anb14 xp8w2v na3oda qi10u5 qr9z5e 1lnf5f9">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:b ...

# %%
# Make the soup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
# First get all of the review-content divs
results = soup.findAll(class_='comment__09f24__gu0rG css-qgunke')
print(results)
# Out:
# [<p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">I took back my 2018 Model 3 last month for safety recall and error on passenger safety belt, nothing to complain, left the car and pickup the next day with $200 uber credit.<br/><br/>The car is beyond satisfying and this location service team is top notch!<br/><br/>Thank you team Van Ness!</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">I went here today to get my front two tires replaced. Tesla's are amazing vehicles, certainly I don't have any problems with the vehicle itself. It's the men working the tire department. I went there and my whole time being there I felt pressured and forced. First an older guy came up to me and checked my front passenger tire out and said it would last a little while more, so a replacement wasn't necessary. Then another gentleman came and was extremely hyper, literally running around and tweaking the whole time. Dude came and checked all 4 of my tires in like 10 seconds max and said I needed 4 tires. Which I agreed with him because I myself knew I needed all 4 to be replaced. Then I'm assuming the "manager" there was also extremely forceful and made me feel pressed. I told them I won't do all 4, I just want to do 2, he said no, but I understand it's for my safety. Then, I agreed to replace all 4 and the cost came out to $1,851.00 for NON-SPORT Michelin tires and I then said I will think about it. So I went to Costco to get an estimate and now I am getting all brand new 4 Michelin Pilot 4 Sport All Season tires for $963. <br/>Go to Costco for your tires!!!!! <br/>Also it's been 8+ hours since I left the service center and my app is still under service!!! Which is extremely frustrating because I need to adjust my charging limit!! <br/>Seriously get new people running the tire department.<br/>Sincerely negative - dissatisfying - disappointing experience today. <br/>Do Better!</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">In a nutshell: Tesla sucks! I leased one of their Model Ys in 2021 and had technical issues within the first month. After a whole year, I had finally gotten them to take the car back and refund the entire year's worth of payments (including down payment &amp; fees). But now, Tesla Insurance is still charging me for month insurance. Worse yet: when I call the 844 number, it's automated system doesn't provide an option for their insurance department... and even when I press any other number for a department, they just leave you on hold listening to some stupid music! I had to call my credit card company to dispute the charge and put a block on them. <br/><br/>Do not buy a Tesla, or you'll be stuck in one or all of these terrible situations!</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Delivery and customer service experience is beyond horrible from Tesla. I've now lost a lot of respect and confidence for Tesla and their cars. They have absolute zero care for their customers and only care about themselves. Not sure if I will ever order another vehicle from Tesla in the future.</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Classic sales person technique. Text you to confirm meeting then when you show up to test drive, they have nothing to even try.  Anthony was all excited to get me to come in, I confirmed the appointment and no one bothered to let us know they had nothing to test drive. A simple call would have saved us time versus getting a nanny to cover while we went to try the model Y. Best excuse was "sorry, we are too busy selling cars to msg you"</span></p>, <p class="comment__09f24__gu0rG css-qgunke"><span class="raw__09f24__T4Ezm" lang="en">Do not get a Tesla.  I have a 2020 Model S Long Range, and the fit and finish on these cars is really bad (on par with the lowest tier of cars).  Us ...

# %%
# Loop through review-content divs and extract paragraph text
reviews = []
for result in results:
  reviews.append(result.find('span').text)

# %%
for review in reviews:
    print(review,'\n')
# Out:
# I took back my 2018 Model 3 last month for safety recall and error on passenger safety belt, nothing to complain, left the car and pickup the next day with $200 uber credit.The car is beyond satisfying and this location service team is top notch!Thank you team Van Ness!
#
# I went here today to get my front two tires replaced. Tesla's are amazing vehicles, certainly I don't have any problems with the vehicle itself. It's the men working the tire department. I went there and my whole time being there I felt pressured and forced. First an older guy came up to me and checked my front passenger tire out and said it would last a little while more, so a replacement wasn't necessary. Then another gentleman came and was extremely hyper, literally running around and tweaking the whole time. Dude came and checked all 4 of my tires in like 10 seconds max and said I needed 4 tires. Which I agreed with him because I myself knew I needed all 4 to be replaced. Then I'm assuming the "manager" there was also extremely forceful and made me feel pressed. I told them I won't do all 4, I just want to do 2, he said no, but I understand it's for my safety. Then, I agreed to replace all 4 and the cost came out to $1,851.00 for NON-SPORT Michelin tires and I then said I will think about it. So I went to Costco to get an estimate and now I am getting all brand new 4 Michelin Pilot 4 Sport All Season tires for $963. Go to Costco for your tires!!!!! Also it's been 8+ hours since I left the service center and my app is still under service!!! Which is extremely frustrating because I need to adjust my charging limit!! Seriously get new people running the tire department.Sincerely negative - dissatisfying - disappointing experience today. Do Better!
#
# In a nutshell: Tesla sucks! I leased one of their Model Ys in 2021 and had technical issues within the first month. After a whole year, I had finally gotten them to take the car back and refund the entire year's worth of payments (including down payment & fees). But now, Tesla Insurance is still charging me for month insurance. Worse yet: when I call the 844 number, it's automated system doesn't provide an option for their insurance department... and even when I press any other number for a department, they just leave you on hold listening to some stupid music! I had to call my credit card company to dispute the charge and put a block on them. Do not buy a Tesla, or you'll be stuck in one or all of these terrible situations!
#
# Delivery and customer service experience is beyond horrible from Tesla. I've now lost a lot of respect and confidence for Tesla and their cars. They have absolute zero care for their customers and only care about themselves. Not sure if I will ever order another vehicle from Tesla in the future.
#
# Classic sales person technique. Text you to confirm meeting then when you show up to test drive, they have nothing to even try.  Anthony was all excited to get me to come in, I confirmed the appointment and no one bothered to let us know they had nothing to test drive. A simple call would have saved us time versus getting a nanny to cover while we went to try the model Y. Best excuse was "sorry, we are too busy selling cars to msg you"
#
# Do not get a Tesla.  I have a 2020 Model S Long Range, and the fit and finish on these cars is really bad (on par with the lowest tier of cars).  User interfaces are garbage, and totally non-intuitive if you have ever driven any kind of car before. Finally, if you dare to need service, it is non-existent.  I got a flat tire tonight (and there is no spare) and sat for two hours waiting for someone from roadside assistance to just answer the phone or get back to me on the app (and no one has gotten back yet).  This car is a piece of crap.  I will never get another Tesla!
#
# Well, I had an issue with my Tesla. Took it into the service center on Thursday. They called me earlier today to tell me to come in and pick up my car and then summarily canceled the Uber voucher that I was given. I'M CURRENTLY ON THE CALTRAIN TO SAVE THEM $ AND NOT USE IT ALL. THEN I WENT TO ORDER A RIDE AND IT SAID CANCELED WOW. Last Tesla I own.
#
# Best service center. The team is very responsive, knowledgeable & friendly. I've visited for glass, filters, tires, front upper control arms, radar & more; always high-quality & lasting repairs, with clear explanations provided.
#
# Nick has been amazing in educating us about the Teslas and answering all of our many questions. There's so much information online that it's overwhelming so it's great to talk to someone in person. Plus Nick was just so wonderful, helpful and trustworthy. It made buying our first new car a great experience and we are so thrilled to have our new Tesla soon! Also it's a huuuuuuge relief to not have to spend energy and time negotiating on price and all that.
#
# Crappy plastic piece falls off the bottom of the model y, exposing all kinds of important hardware, so often they make an aftermarket replacement for it but tesla doesn't cover it under their warranty! They charged me $250 for something that should be covered by warranty. I'll be waiting for the recall to get my money back.

# %%
reviews[0]
# Out:
# 'I took back my 2018 Model 3 last month for safety recall and error on passenger safety belt, nothing to complain, left the car and pickup the next day with $200 uber credit.The car is beyond satisfying and this location service team is top notch!Thank you team Van Ness!'

# %%
#ANALYSE THE DATA

# %%
import numpy as np
import pandas as pd

# %%
# Create a pandas dataframe from array
df = pd.DataFrame(np.array(reviews), columns=['review'])

# %%
df.head()
# Out:
#                                               review
# 0  I took back my 2018 Model 3 last month for saf...
# 1  I went here today to get my front two tires re...
# 2  In a nutshell: Tesla sucks! I leased one of th...
# 3  Delivery and customer service experience is be...
# 4  Classic sales person technique. Text you to co...

# %%
len(df['review'])
# Out:
# 10

# %%
df['word_count'] = df['review'].apply(lambda x: len(str(x).split(" ")))

# %%
# Calculate character count
df['char_count'] = df['review'].str.len()

# %%
def avg_word(review):
  words = review.split()
  return (sum(len(word) for word in words) / len(words))

# Calculate average words
df['avg_word'] = df['review'].apply(lambda x: avg_word(x))

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (3.8.1)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from click->nltk) (0.4.5)

# %%
# Import stopwords
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')
df['stopword_coun'] = df['review'].apply(lambda x: len([x for x in x.split() if x in stop_words]))

# %%
df.describe()
# Out:
#        word_count   char_count   avg_word  stopword_coun
# count   10.000000    10.000000  10.000000      10.000000
# mean    95.500000   514.800000   4.527666      36.300000
# std     69.739595   369.684791   0.588395      26.973444
# min     33.000000   228.000000   3.808219       4.000000
# 25%     52.500000   303.250000   4.177389      21.000000
# 50%     78.000000   394.500000   4.467512      30.500000
# 75%    107.000000   546.000000   4.675016      45.250000
# max    273.000000  1472.000000   5.939394      99.000000

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  I took back my 2018 Model 3 last month for saf...          49         270
# 1  I went here today to get my front two tires re...         273        1472
# 2  In a nutshell: Tesla sucks! I leased one of th...         136         734
# 3  Delivery and customer service experience is be...          51         296
# 4  Classic sales person technique. Text you to co...          86         439
#
#    avg_word  stopword_coun
# 0  4.530612             14
# 1  4.395604             99
# 2  4.404412             56
# 3  4.823529             21
# 4  4.104651             34

# %%
# Lower case all words
df['review_lower'] = df['review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
# Remove Punctuation
df['review_nopunc'] = df['review_lower'].str.replace('[^\w\s]', '')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10904\2242441639.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['review_nopunc'] = df['review_lower'].str.replace('[^\w\s]', '')

# %%
stop_words = stopwords.words('english')

# %%
# Remove Stopwords
df['review_nopunc_nostop'] = df['review_nopunc'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

# %%
# Return frequency of values
freq= pd.Series(" ".join(df['review_nopunc_nostop']).split()).value_counts()[:30]
print(freq)
# Out:
# tesla         12
# get            8
# service        7
# tires          7
# car            7
# 4              7
# back           5
# went           5
# said           5
# model          5
# came           4
# time           4
# cars           4
# new            4
# one            4
# tire           4
# us             3
# extremely      3
# call           3
# front          3
# also           3
# today          3
# insurance      3
# department     3
# whole          3
# first          3
# another        3
# center         3
# month          3
# nothing        3
# dtype: int64

# %%
other_stopwords = ['tesla', 'get', 'service', 'tires', 'car', '4', 'back', 'went' \
  'said', 'model', 'came', 'time', 'cars', 'new', 'one', \
  'tire', 'us', 'extremely', 'call', 'front', 'also', 'today', 'insurance', \
  'department', 'whole', 'first', 'another', 'center','month','nothing']

# %%
df['review_nopunc_nostop_nocommon'] = df['review_nopunc_nostop'].apply(lambda x: "".join(" ".join(x for x in x.split() if x not in other_stopwords)))

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  I took back my 2018 Model 3 last month for saf...          49         270
# 1  I went here today to get my front two tires re...         273        1472
# 2  In a nutshell: Tesla sucks! I leased one of th...         136         734
# 3  Delivery and customer service experience is be...          51         296
# 4  Classic sales person technique. Text you to co...          86         439
#
#    avg_word  stopword_coun                                       review_lower  \
# 0  4.530612             14  i took back my 2018 model 3 last month for saf...
# 1  4.395604             99  i went here today to get my front two tires re...
# 2  4.404412             56  in a nutshell: tesla sucks! i leased one of th...
# 3  4.823529             21  delivery and customer service experience is be...
# 4  4.104651             34  classic sales person technique. text you to co...
#
#                                        review_nopunc  \
# 0  i took back my 2018 model 3 last month for saf...
# 1  i went here today to get my front two tires re...
# 2  in a nutshell tesla sucks i leased one of thei...
# 3  delivery and customer service experience is be...
# 4  classic sales person technique text you to con...
#
#                                 review_nopunc_nostop  \
# 0  took back 2018 model 3 last month safety recal...
# 1  went today get front two tires replaced teslas...
# 2  nutshell tesla sucks leased one model ys 2021 ...
# 3  delivery customer service experience beyond ho...
# 4  classic sales person technique text confirm me...
#
#                        review_nopunc_nostop_nocommon
# 0  took 2018 3 last safety recall error passenger...
# 1  went two replaced teslas amazing vehicles cert...
# 2  nutshell sucks leased ys 2021 technical issues...
# 3  delivery customer experience beyond horrible i...
# 4  classic sales person technique text confirm me...

# %%
! pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      -------------------------------------- 636.8/636.8 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from nltk>=3.1->textblob) (2022.10.31)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %%
from textblob import Word

# %%
# Lemmatize final review format
nltk.download('wordnet')
df['cleaned_review'] = df['review_nopunc_nostop_nocommon']\
.apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...

# %%
# Calculate polarity
from textblob import TextBlob

# %%
df['polarity'] = df['cleaned_review'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df[['review','polarity']]
# Out:
#                                               review  polarity
# 0  I took back my 2018 Model 3 last month for saf...  0.200000
# 1  I went here today to get my front two tires re... -0.045706
# 2  In a nutshell: Tesla sucks! I leased one of th... -0.271429
# 3  Delivery and customer service experience is be... -0.075000
# 4  Classic sales person technique. Text you to co...  0.186458
# 5  Do not get a Tesla.  I have a 2020 Model S Lon... -0.071875
# 6  Well, I had an issue with my Tesla. Took it in...  0.025000
# 7  Best service center. The team is very responsi...  0.295000
# 8  Nick has been amazing in educating us about th...  0.625000
# 9  Crappy plastic piece falls off the bottom of t...  0.166667

# %%
# Calculate subjectivity
df['subjectivity'] = df['cleaned_review'].apply(lambda x: TextBlob(x).sentiment[1])

# %%
df[['review','subjectivity']]
# Out:
#                                               review  subjectivity
# 0  I took back my 2018 Model 3 last month for saf...      0.313333
# 1  I went here today to get my front two tires re...      0.481293
# 2  In a nutshell: Tesla sucks! I leased one of th...      0.632143
# 3  Delivery and customer service experience is be...      0.728472
# 4  Classic sales person technique. Text you to co...      0.490476
# 5  Do not get a Tesla.  I have a 2020 Model S Lon...      0.630208
# 6  Well, I had an issue with my Tesla. Took it in...      0.491667
# 7  Best service center. The team is very responsi...      0.236667
# 8  Nick has been amazing in educating us about th...      0.725000
# 9  Crappy plastic piece falls off the bottom of t...      0.966667
